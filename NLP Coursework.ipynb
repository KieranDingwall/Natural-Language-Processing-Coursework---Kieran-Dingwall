# %% [markdown]
# # Natural Language Processing Coursework

# %% [markdown]
# By Kieran Dingwall - Student Number: 2208619

# %% [markdown]
# ### Section 1 - Dataset Exploring and Pre Processing

# %%
# Imports
import pandas as pd
import numpy as np 
# import io 

# Load Dataset
product_data = pd.read_csv("pricerunner_aggregate.csv")
print(product_data)
# Out:
#        Product ID                                      Product Title  \
# 0               1                    apple iphone 8 plus 64gb silver
# 1               2                apple iphone 8 plus 64 gb spacegrau
# 2               3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3               4                apple iphone 8 plus 64gb space grey
# 4               5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
# ...           ...                                                ...
# 35306       47350  smeg fab28 60cm retro style right hand hinge f...
# 35307       47351  smeg fab28 60cm retro style left hand hinge fr...
# 35308       47352  smeg fab28 60cm retro style left hand hinge fr...
# 35309       47355     candy 60cm built under larder fridge cru160nek
# 35310       47358           neff k4316x7gb built under larder fridge
#
#         Merchant ID   Cluster ID             Cluster Label   Category ID  \
# 0                 1            1  Apple iPhone 8 Plus 64GB          2612
# 1                 2            1  Apple iPhone 8 Plus 64GB          2612
# 2                 3            1  Apple iPhone 8 Plus 64GB          2612
# 3                 4            1  Apple iPhone 8 Plus 64GB          2612
# 4                 5            1  Apple iPhone 8 Plus 64GB          2612
# ...             ...          ...                       ...           ...
# 35306            59        47517          Smeg FAB28 Cream          2623
# 35307            59        47518            Smeg FAB28 Red          2623
# 35308            59        47519           Smeg FAB28 Pink          2623
# 35309           125        47524             Candy CRU16.0          2623
# 35310           179        47525                Neff K4316          2623
#
#        Category Label
# 0       Mobile Phones
# 1       Mobile Phones
# 2       Mobile Phones
# 3       Mobile Phones
# 4       Mobile Phones
# ...               ...
# 35306         Fridges
# 35307         Fridges
# 35308         Fridges
# 35309         Fridges
# 35310         Fridges
#
# [35311 rows x 7 columns]

# %%
# Remove unused columns from data 
product_df = product_data.drop(product_data.columns[[0, 2, 3, 5]], axis=1)
print(product_df)
# Out:
#                                            Product Title  \
# 0                        apple iphone 8 plus 64gb silver
# 1                    apple iphone 8 plus 64 gb spacegrau
# 2      apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3                    apple iphone 8 plus 64gb space grey
# 4      apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
# ...                                                  ...
# 35306  smeg fab28 60cm retro style right hand hinge f...
# 35307  smeg fab28 60cm retro style left hand hinge fr...
# 35308  smeg fab28 60cm retro style left hand hinge fr...
# 35309     candy 60cm built under larder fridge cru160nek
# 35310           neff k4316x7gb built under larder fridge
#
#                   Cluster Label  Category Label
# 0      Apple iPhone 8 Plus 64GB   Mobile Phones
# 1      Apple iPhone 8 Plus 64GB   Mobile Phones
# 2      Apple iPhone 8 Plus 64GB   Mobile Phones
# 3      Apple iPhone 8 Plus 64GB   Mobile Phones
# 4      Apple iPhone 8 Plus 64GB   Mobile Phones
# ...                         ...             ...
# 35306          Smeg FAB28 Cream         Fridges
# 35307            Smeg FAB28 Red         Fridges
# 35308           Smeg FAB28 Pink         Fridges
# 35309             Candy CRU16.0         Fridges
# 35310                Neff K4316         Fridges
#
# [35311 rows x 3 columns]

# %%
# Convert the feature columns into a numpy array
x = product_df[["Product Title", " Cluster Label"]].to_numpy() 
y = product_df[[" Category Label"]].to_numpy() 
#print(x) #feel free to uncomment and check the output
#print(y)
# Out:
# [['apple iphone 8 plus 64gb silver' 'Apple iPhone 8 Plus 64GB']
#  ['apple iphone 8 plus 64 gb spacegrau' 'Apple iPhone 8 Plus 64GB']
#  ['apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim free smartphone in gold'
#   'Apple iPhone 8 Plus 64GB']
#  ...
#  ['smeg fab28 60cm retro style left hand hinge fridge with icebox pink'
#   'Smeg FAB28 Pink']
#  ['candy 60cm built under larder fridge cru160nek' 'Candy CRU16.0']
#  ['neff k4316x7gb built under larder fridge' 'Neff K4316']]
# [['Mobile Phones']
#  ['Mobile Phones']
#  ['Mobile Phones']
#  ...
#  ['Fridges']
#  ['Fridges']
#  ['Fridges']]

# %%
from sklearn.model_selection import StratifiedKFold #cross fold is sometimes called k-fold. Calling the stratified version ensures that classes have equal representation across folds
from sklearn.neighbors import KNeighborsClassifier #importing the knn model
from sklearn.metrics import accuracy_score #import an accuracy metric to tell us how well the model is doing

acc_score = [] #create a list to store the accuracy values

kf = StratifiedKFold(n_splits=5) #we instantiate the kfold instance, and set the number of folds to 5
for train, test in kf.split(x,y): #we use a for loop to iterate through each fold using the train and test indexes from the dataset

  model = KNeighborsClassifier(n_neighbors=3, metric="cosine", weights="uniform") #instantiate the model
  x_train, x_test, y_train, y_test = x[train], x[test], y[train], y[test] #things can get a bit weird when inputting indexes to functions, so lets save them as variables

  model.fit(x_train, y_train) #we then only fit the training data
  predictions = model.predict(x_test) #and can predict on the test data
  acc = accuracy_score(predictions, y_test) #we use the accuracy score we imported to give an idea how well the model is doing
  acc_score.append(acc) #we can append it to our list

print(acc_score) #wowza, looks ike it's pretty good!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 13
#      10 model = KNeighborsClassifier(n_neighbors=3, metric="cosine", weights="uniform") #instantiate the model
#      11 x_train, x_test, y_train, y_test = x[train], x[test], y[train], y[test] #things can get a bit weird when inputting indexes to functions, so lets save them as variables
# ---> 13 model.fit(x_train, y_train) #we then only fit the training data
#      14 predictions = model.predict(x_test) #and can predict on the test data
#      15 acc = accuracy_score(predictions, y_test) #we use the accuracy score we imported to give an idea how well the model is doing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239, in KNeighborsClassifier.fit(self, X, y)
#     217 @_fit_context(
#     218     # KNeighborsClassifier.metric is not validated yet
#     219     prefer_skip_nested_validation=False
#     220 )
#     221 def fit(self, X, y):
#     222     """Fit the k-nearest neighbors classifier from the training dataset.
#     223
#     224     Parameters
#    (...)
#     237         The fitted k-nearest neighbors classifier.
#     238     """
# --> 239     return self._fit(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_base.py:478, in NeighborsBase._fit(self, X, y)
#     476 if self.__sklearn_tags__().target_tags.required:
#     477     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 478         X, y = validate_data(
#     479             self,
#     480             X,
#     481             y,
#     482             accept_sparse="csr",
#     483             multi_output=True,
#     484             order="C",
#     485             ensure_all_finite=ensure_all_finite,
#     486         )
#     488     if is_classifier(self):
#     489         # Classification targets require a specific format
#     490         if y.ndim == 1 or (y.ndim == 2 and y.shape[1] == 1):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'huawei p20 lite single sim 4g 64gb black blue smartphones 14.8 cm 5.84 64 gb 16 mp android 8.0 oreo emui 8.0 black blue'

# %% [markdown]
# ### Section 2 - Representation Learning

# %% [markdown]
# ### Section 3 - Algorithms

# %% [markdown]
# ### Section 4 - Evaluation
